# %% [markdown]
# <a href="https://colab.research.google.com/github/AmrithavarshiniR/OpenAITraining/blob/main/Sep24_002_Weights_and_bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome back!

# %% [markdown]
# In this lab, we will observe how weights and bias are trained over epochs.

# %% [markdown]
# Let's begin with importing the libraries and read the dataset. We will also break the dataset into features and labels.

# %%
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
#IGNORE ANY WARNINGS THAT MAY APPEAR ON THIS CELL

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/EY_batch6_2ndSep24/main/data.csv')

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/EY_batch6_2ndSep24/main/data.csv')
data.tail(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559  925291         B        11.51         23.93           74.52      403.5
# 560  925292         B        14.05         27.15           91.38      600.4
# 561  925311         B        11.20         29.37           70.67      386.0
# 562  925622         M        15.22         30.62          103.40      716.9
# 563  926125         M        20.92         25.09          143.00     1347.0
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 559          0.09261           0.10210         0.11120              0.04105
# 560          0.09929           0.11260         0.04462              0.04304
# 561          0.07449           0.03558         0.00000              0.00000
# 562          0.10480           0.20870         0.25500              0.09429
# 563          0.10990           0.22360         0.31740              0.14740
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 559  ...          37.16            82.28       474.2           0.12980
# 560  ...          33.17           100.20       706.7           0.12410
# 561  ...          38.30            75.19       439.6           0.09267
# 562  ...          42.79           128.70       915.0           0.14170
# 563  ...          29.41           179.10      1819.0           0.14070
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 559            0.25170           0.3630               0.09653          0.2112
# 560            0.22640           0.1326               0.10480          0.2250
# 561            0.05494           0.0000               0.00000          0.1566
# 562            0.79170           1.1700               0.23560          0.4089
# 563            0.41860           0.6599               0.25420          0.2929
# 564            0.21130           0.4107               0.22160          0.2060
# 565            0.19220           0.3215               0.16280          0.2572
# 566            0.30940           0.3403               0.14180          0.2218
# 567            0.86810           0.9387               0.26500          0.4087
# 568            0.06444           0.0000               0.00000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 559                  0.08732          NaN
# 560                  0.08321          NaN
# 561                  0.05905          NaN
# 562                  0.14090          NaN
# 563                  0.09873          NaN
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [10 rows x 33 columns]

# %%
data
# Out:
# <tf.Tensor: shape=(16, 2), dtype=float64, numpy=
# array([[-0.37663829, -1.13197783],
#        [ 1.53309688, -0.864631  ],
#        [ 1.38837698, -0.43161447],
#        [ 0.57964812,  0.17347103],
#        [-0.46460529, -0.79992738],
#        [ 1.53877217,  0.32989736],
#        [ 1.55012275,  1.11202903],
#        [-0.47311823, -1.60978917],
#        [-0.38515123, -0.96701915],
#        [-0.15246433, -1.19454836],
#        [ 0.08306022,  0.08245935],
#        [ 0.83787382,  0.18626955],
#        [-0.0247703 , -0.83761191],
#        [ 0.12846254,  0.64275003],
#        [-0.75972039,  0.98404385],
#        [-0.19502901, -1.04807643]])>

# %%
x = data[['radius_mean', 'smoothness_mean', 'area_mean']]
y = data[['diagnosis']]

# %% [markdown]
# We are using the same dataset as in the last lab- view the inputs and labels.

# %%
x.head()
# Out:
#    radius_mean  smoothness_mean  area_mean
# 0        17.99          0.11840     1001.0
# 1        20.57          0.08474     1326.0
# 2        19.69          0.10960     1203.0
# 3        11.42          0.14250      386.1
# 4        20.29          0.10030     1297.0

# %%
y.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %% [markdown]
# Using the same process as the last lab, we will normalize the inputs, and encode the labels.

# %% [markdown]
# Why do we normalize?
#
# happiness = f(money, age)
#
# age -> [0, 100]
#
# money -> [ -$1,000,000,000 , $1,000,000,000 ]
#
# h = w1*age + w2*money + bias
#
# solution -> bring all in same level
#
# age -> [-1,1]
# money -> [-1 to 1]
#
# many ways to do this:
#
# 1. Z-Score : (data - mean) / standard_deviation
#
# scales everything on scale of (-inf, inf) such that the mean value becomes 0, and all others are adjusted as its ratio
#
# From this, we create a scale of (-3, 3) which means 3 times of standard deviation is allowed!
#
# Anything > 3 or < -3 is called an -> OUTLIER
#
#
# 2. Min Max : (data - min ) / (max - min)
#
# Scale-> [ 0 to 1]
#
# largest-> 1, smallest-> 0, everything else adjusted between them
#
# Use case-> images -> [0,255] where each pixel is 1 byte or 0 to 255.
#
# image normlization-> data / 255.0
#
#
# 3. Sigmoid: (use TF instead of formula)
# Scale -> [0 to 1] BUT PROBABILISTIC unlike MinMAX!
#
# 4. TanH: hyperbolic tangent -> USE TF instead of formula
#
# Scale -> [-1 to 1] -> probaility, classification

# %%
x.describe().T
# Out:
#                  count        mean         std        min        25%  \
# radius_mean      569.0   14.127292    3.524049    6.98100   11.70000
# smoothness_mean  569.0    0.096360    0.014064    0.05263    0.08637
# area_mean        569.0  654.889104  351.914129  143.50000  420.30000
#
#                        50%       75%        max
# radius_mean       13.37000   15.7800    28.1100
# smoothness_mean    0.09587    0.1053     0.1634
# area_mean        551.10000  782.7000  2501.0000

# %%
#Normalize Input
stats = x.describe().T
mu, sigma = stats['mean'], stats['std']

# %%
x
# Out:
#      radius_mean  smoothness_mean  area_mean
# 0          17.99          0.11840     1001.0
# 1          20.57          0.08474     1326.0
# 2          19.69          0.10960     1203.0
# 3          11.42          0.14250      386.1
# 4          20.29          0.10030     1297.0
# ..           ...              ...        ...
# 564        21.56          0.11100     1479.0
# 565        20.13          0.09780     1261.0
# 566        16.60          0.08455      858.1
# 567        20.60          0.11780     1265.0
# 568         7.76          0.05263      181.0
#
# [569 rows x 3 columns]

# %%
mu
# Out:
# radius_mean         14.127292
# smoothness_mean      0.096360
# area_mean          654.889104
# Name: mean, dtype: float64

# %%
sigma
# Out:
# radius_mean          3.524049
# smoothness_mean      0.014064
# area_mean          351.914129
# Name: std, dtype: float64

# %%
x_norm = (x-mu)/sigma

# %%
x_norm
# Out:
#      radius_mean  smoothness_mean  area_mean
# 0       1.096100         1.567087   0.983510
# 1       1.828212        -0.826235   1.907030
# 2       1.578499         0.941382   1.557513
# 3      -0.768233         3.280667  -0.763792
# 4       1.748758         0.280125   1.824624
# ..           ...              ...        ...
# 564     2.109139         1.040926   2.341795
# 565     1.703356         0.102368   1.722326
# 566     0.701667        -0.839745   0.577445
# 567     1.836725         1.524426   1.733693
# 568    -1.806811        -3.109349  -1.346604
#
# [569 rows x 3 columns]

# %%
rule = lambda val: 1 if val=='M' else 0

# %%
y=y['diagnosis'].apply(rule)

# %%
y.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %% [markdown]
# Now we will proceed to splitting the data. No changes so far-

# %%
HP_epochs = 200
HP_batch_size = 16
HP_lr = 0.001

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_norm,y,random_state=42, test_size=0.2)

# %%
xtest
# Out:
#      radius_mean  smoothness_mean  area_mean
# 204    -0.470281         0.233908  -0.491566
# 70      1.365676        -0.445835   1.350076
# 131     0.378175         0.912941   0.267142
# 431    -0.490144         0.642750  -0.531633
# 540    -0.734182         0.247418  -0.716053
# ..           ...              ...        ...
# 486     0.145488        -0.707494   0.031573
# 75      0.551272        -0.332781   0.462644
# 249    -0.739857         0.351228  -0.706391
# 238     0.026307        -1.004704  -0.088059
# 265     1.873614        -0.118762   2.171299
#
# [114 rows x 3 columns]

# %%
xtrain
# Out:
#      radius_mean  smoothness_mean  area_mean
# 68     -1.446714         0.728073  -1.149113
# 181     1.975770         1.261345   1.864406
# 63     -1.405852        -1.361640  -1.119560
# 248    -0.986732         0.014912  -0.874898
# 60     -1.122939         1.211573  -0.974639
# ..           ...              ...        ...
# 71     -1.486725         0.104501  -1.167583
# 106    -0.705805         1.268455  -0.688773
# 270     0.046171        -2.280289  -0.063337
# 435    -0.041796         0.685412  -0.157394
# 102    -0.552572        -1.154020  -0.557491
#
# [455 rows x 3 columns]

# %% [markdown]
# Our dataset is small. But for big data, or larger datasets, we can use TensorFlow's Dataset API.
# <br/>
# We additionally shuffle the dataset to provide randomness.
#
# Because we are going to simulate the training process over epochs, we will also repeat our dataset.
#
# We will also divide our data into fixed size batches.

# %%
celldata = tf.data.Dataset.from_tensor_slices((xtrain,ytrain))
celldata = celldata.shuffle(100).repeat(HP_epochs).batch(HP_batch_size)

# %% [markdown]
# This is the simplest way to create a dataset.
#
# dataset = tf.data.Dataset.from_tensor_slices(any_tensor_or_numpy_array_or_pandas_dataset)

# %% [markdown]
# Now we will place an iterator on top of our dataset to loop into the actual data.

# %%
itr = celldata.__iter__()
#IGNORE ANY WARNINGS THAT MAY APPEAR ON THIS CELL

# %% [markdown]
# Now, we will initialize our weights and bias. We are initializing the weights with random numbers, normally distributed from the mean 0, with a standard deviation of 0.5.

# %%
# we have only 2 features and 1 label
# One weight for each feature
w = tf.random.normal( ( 3 , 1 ), mean = 0, stddev =0.5,dtype=tf.dtypes.double )
# One bias for every output
# our only output is the label prediction on 1 layer
b = 0

# %% [markdown]
# Have a look at the initial weights

# %%
print(w)
# Out:
# tf.Tensor(
# [[-0.12434767]
#  [-0.26693111]
#  [ 0.60062191]], shape=(3, 1), dtype=float64)

# %%
# define an empty array to store all the errors
# errors will be generated from each training simulation
err = []

# %% [markdown]
# Let's define a dummy classifier to encode our predictions into 1 and 0

# %%
def myclassifier(vals):
  res = []
  rule = lambda r: 1.0 if r>=0.5 else 0.0
  for val in vals:
    res.append(rule(val))
  return res

# %% [markdown]
# And let's begin the training simulation!

# %% [markdown]
# TensorFlow functions to observe
#
#
# *   tensordot - returns dot product
# *   cast - datatype casting on tensors
# *   reduce_mean - mean of TensorFlow datasets

# %%
itrs_per_epoch = int(len(xtrain)/HP_batch_size)
# Each iteration represents 1 epoch
for i in range(HP_epochs):
  per_iter_err = []
  for j in range(itrs_per_epoch):
    # get data and labels in fixed batch sizes
    data, labels = itr.get_next()

    # simplest representation of ML
    # y = mx + c
    y = tf.tensordot(data, w, axes=1) + b
    # decode the results, and typecast to double
    y = myclassifier(y)
    y = tf.cast(y, tf.dtypes.double)
    # typecast the known labels to double
    labels = tf.cast(labels, tf.dtypes.double)
    # calculate the error
    avg_error = tf.reduce_mean(tf.square(y - labels))
    per_iter_err.append(avg_error)
    mse_derivative = tf.reduce_mean(2 * ( y - labels ))

    # update the weights and bias for the next epoch
    weight_update = tf.reduce_mean(mse_derivative*data)
    bias_update = tf.reduce_mean(mse_derivative)

    w = w - HP_lr * weight_update
    b = b - HP_lr * bias_update
    # end of iteration simulation

  final_epoch_error = np.array(per_iter_err).mean()
  err.append(final_epoch_error)
  #end of epoch simulation

  print('****')
  print('For epoch ',i+1,', the weights = ', w)
# Out:
# ****
# For epoch  1 , the weights =  tf.Tensor(
# [[-0.12415953]
#  [-0.26674297]
#  [ 0.60081005]], shape=(3, 1), dtype=float64)
# ****
# For epoch  2 , the weights =  tf.Tensor(
# [[-0.12425737]
#  [-0.26684082]
#  [ 0.60071221]], shape=(3, 1), dtype=float64)
# ****
# For epoch  3 , the weights =  tf.Tensor(
# [[-0.1242829 ]
#  [-0.26686635]
#  [ 0.60068667]], shape=(3, 1), dtype=float64)
# ****
# For epoch  4 , the weights =  tf.Tensor(
# [[-0.12430231]
#  [-0.26688576]
#  [ 0.60066726]], shape=(3, 1), dtype=float64)
# ****
# For epoch  5 , the weights =  tf.Tensor(
# [[-0.1242837 ]
#  [-0.26686715]
#  [ 0.60068587]], shape=(3, 1), dtype=float64)
# ****
# For epoch  6 , the weights =  tf.Tensor(
# [[-0.12408657]
#  [-0.26667002]
#  [ 0.60088301]], shape=(3, 1), dtype=float64)
# ****
# For epoch  7 , the weights =  tf.Tensor(
# [[-0.12414378]
#  [-0.26672722]
#  [ 0.6008258 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  8 , the weights =  tf.Tensor(
# [[-0.12388933]
#  [-0.26647278]
#  [ 0.60108024]], shape=(3, 1), dtype=float64)
# ****
# For epoch  9 , the weights =  tf.Tensor(
# [[-0.12396932]
#  [-0.26655277]
#  [ 0.60100026]], shape=(3, 1), dtype=float64)
# ****
# For epoch  10 , the weights =  tf.Tensor(
# [[-0.12388584]
#  [-0.26646929]
#  [ 0.60108373]], shape=(3, 1), dtype=float64)
# ****
# For epoch  11 , the weights =  tf.Tensor(
# [[-0.12357804]
#  [-0.26616149]
#  [ 0.60139153]], shape=(3, 1), dtype=float64)
# ****
# For epoch  12 , the weights =  tf.Tensor(
# [[-0.12352891]
#  [-0.26611236]
#  [ 0.60144067]], shape=(3, 1), dtype=float64)
# ****
# For epoch  13 , the weights =  tf.Tensor(
# [[-0.12363475]
#  [-0.26621819]
#  [ 0.60133483]], shape=(3, 1), dtype=float64)
# ****
# For epoch  14 , the weights =  tf.Tensor(
# [[-0.12332582]
#  [-0.26590926]
#  [ 0.60164376]], shape=(3, 1), dtype=float64)
# ****
# For epoch  15 , the weights =  tf.Tensor(
# [[-0.12333575]
#  [-0.26591919]
#  [ 0.60163383]], shape=(3, 1), dtype=float64)
# ****
# For epoch  16 , the weights =  tf.Tensor(
# [[-0.12355332]
#  [-0.26613677]
#  [ 0.60141626]], shape=(3, 1), dtype=float64)
# ****
# For epoch  17 , the weights =  tf.Tensor(
# [[-0.12262617]
#  [-0.26520962]
#  [ 0.60234341]], shape=(3, 1), dtype=float64)
# ****
# For epoch  18 , the weights =  tf.Tensor(
# [[-0.12230172]
#  [-0.26488516]
#  [ 0.60266786]], shape=(3, 1), dtype=float64)
# ****
# For epoch  19 , the weights =  tf.Tensor(
# [[-0.12178157]
#  [-0.26436502]
#  [ 0.603188  ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  20 , the weights =  tf.Tensor(
# [[-0.12154641]
#  [-0.26412985]
#  [ 0.60342317]], shape=(3, 1), dtype=float64)
# ****
# For epoch  21 , the weights =  tf.Tensor(
# [[-0.12139196]
#  [-0.2639754 ]
#  [ 0.60357762]], shape=(3, 1), dtype=float64)
# ****
# For epoch  22 , the weights =  tf.Tensor(
# [[-0.12140309]
#  [-0.26398654]
#  [ 0.60356649]], shape=(3, 1), dtype=float64)
# ****
# For epoch  23 , the weights =  tf.Tensor(
# [[-0.12150617]
#  [-0.26408962]
#  [ 0.60346341]], shape=(3, 1), dtype=float64)
# ****
# For epoch  24 , the weights =  tf.Tensor(
# [[-0.1210878 ]
#  [-0.26367124]
#  [ 0.60388178]], shape=(3, 1), dtype=float64)
# ****
# For epoch  25 , the weights =  tf.Tensor(
# [[-0.12081711]
#  [-0.26340055]
#  [ 0.60415247]], shape=(3, 1), dtype=float64)
# ****
# For epoch  26 , the weights =  tf.Tensor(
# [[-0.1204911 ]
#  [-0.26307455]
#  [ 0.60447847]], shape=(3, 1), dtype=float64)
# ****
# For epoch  27 , the weights =  tf.Tensor(
# [[-0.12012186]
#  [-0.2627053 ]
#  [ 0.60484772]], shape=(3, 1), dtype=float64)
# ****
# For epoch  28 , the weights =  tf.Tensor(
# [[-0.11971334]
#  [-0.26229679]
#  [ 0.60525624]], shape=(3, 1), dtype=float64)
# ****
# For epoch  29 , the weights =  tf.Tensor(
# [[-0.11959849]
#  [-0.26218193]
#  [ 0.60537109]], shape=(3, 1), dtype=float64)
# ****
# For epoch  30 , the weights =  tf.Tensor(
# [[-0.11928692]
#  [-0.26187037]
#  [ 0.60568266]], shape=(3, 1), dtype=float64)
# ****
# For epoch  31 , the weights =  tf.Tensor(
# [[-0.11897984]
#  [-0.26156328]
#  [ 0.60598974]], shape=(3, 1), dtype=float64)
# ****
# For epoch  32 , the weights =  tf.Tensor(
# [[-0.11867979]
#  [-0.26126323]
#  [ 0.60628979]], shape=(3, 1), dtype=float64)
# ****
# For epoch  33 , the weights =  tf.Tensor(
# [[-0.11900756]
#  [-0.26159101]
#  [ 0.60596202]], shape=(3, 1), dtype=float64)
# ****
# For epoch  34 , the weights =  tf.Tensor(
# [[-0.11838888]
#  [-0.26097233]
#  [ 0.6065807 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  35 , the weights =  tf.Tensor(
# [[-0.11803772]
#  [-0.26062117]
#  [ 0.60693186]], shape=(3, 1), dtype=float64)
# ****
# For epoch  36 , the weights =  tf.Tensor(
# [[-0.1179378 ]
#  [-0.26052125]
#  [ 0.60703178]], shape=(3, 1), dtype=float64)
# ****
# For epoch  37 , the weights =  tf.Tensor(
# [[-0.11751807]
#  [-0.26010152]
#  [ 0.6074515 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  38 , the weights =  tf.Tensor(
# [[-0.11734241]
#  [-0.25992585]
#  [ 0.60762717]], shape=(3, 1), dtype=float64)
# ****
# For epoch  39 , the weights =  tf.Tensor(
# [[-0.11730435]
#  [-0.2598878 ]
#  [ 0.60766523]], shape=(3, 1), dtype=float64)
# ****
# For epoch  40 , the weights =  tf.Tensor(
# [[-0.11692195]
#  [-0.25950539]
#  [ 0.60804763]], shape=(3, 1), dtype=float64)
# ****
# For epoch  41 , the weights =  tf.Tensor(
# [[-0.11674302]
#  [-0.25932646]
#  [ 0.60822656]], shape=(3, 1), dtype=float64)
# ****
# For epoch  42 , the weights =  tf.Tensor(
# [[-0.11604947]
#  [-0.25863291]
#  [ 0.60892011]], shape=(3, 1), dtype=float64)
# ****
# For epoch  43 , the weights =  tf.Tensor(
# [[-0.1160381 ]
#  [-0.25862154]
#  [ 0.60893148]], shape=(3, 1), dtype=float64)
# ****
# For epoch  44 , the weights =  tf.Tensor(
# [[-0.11555107]
#  [-0.25813452]
#  [ 0.6094185 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  45 , the weights =  tf.Tensor(
# [[-0.11551192]
#  [-0.25809537]
#  [ 0.60945766]], shape=(3, 1), dtype=float64)
# ****
# For epoch  46 , the weights =  tf.Tensor(
# [[-0.11499096]
#  [-0.25757441]
#  [ 0.60997861]], shape=(3, 1), dtype=float64)
# ****
# For epoch  47 , the weights =  tf.Tensor(
# [[-0.11424981]
#  [-0.25683326]
#  [ 0.61071977]], shape=(3, 1), dtype=float64)
# ****
# For epoch  48 , the weights =  tf.Tensor(
# [[-0.1136853 ]
#  [-0.25626875]
#  [ 0.61128428]], shape=(3, 1), dtype=float64)
# ****
# For epoch  49 , the weights =  tf.Tensor(
# [[-0.11329039]
#  [-0.25587384]
#  [ 0.61167919]], shape=(3, 1), dtype=float64)
# ****
# For epoch  50 , the weights =  tf.Tensor(
# [[-0.11297404]
#  [-0.25555748]
#  [ 0.61199554]], shape=(3, 1), dtype=float64)
# ****
# For epoch  51 , the weights =  tf.Tensor(
# [[-0.11246577]
#  [-0.25504922]
#  [ 0.6125038 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  52 , the weights =  tf.Tensor(
# [[-0.11166719]
#  [-0.25425064]
#  [ 0.61330239]], shape=(3, 1), dtype=float64)
# ****
# For epoch  53 , the weights =  tf.Tensor(
# [[-0.11096046]
#  [-0.25354391]
#  [ 0.61400911]], shape=(3, 1), dtype=float64)
# ****
# For epoch  54 , the weights =  tf.Tensor(
# [[-0.11044629]
#  [-0.25302974]
#  [ 0.61452329]], shape=(3, 1), dtype=float64)
# ****
# For epoch  55 , the weights =  tf.Tensor(
# [[-0.10970338]
#  [-0.25228683]
#  [ 0.61526619]], shape=(3, 1), dtype=float64)
# ****
# For epoch  56 , the weights =  tf.Tensor(
# [[-0.10907865]
#  [-0.2516621 ]
#  [ 0.61589092]], shape=(3, 1), dtype=float64)
# ****
# For epoch  57 , the weights =  tf.Tensor(
# [[-0.10850116]
#  [-0.2510846 ]
#  [ 0.61646842]], shape=(3, 1), dtype=float64)
# ****
# For epoch  58 , the weights =  tf.Tensor(
# [[-0.1079806 ]
#  [-0.25056404]
#  [ 0.61698898]], shape=(3, 1), dtype=float64)
# ****
# For epoch  59 , the weights =  tf.Tensor(
# [[-0.10699639]
#  [-0.24957983]
#  [ 0.61797319]], shape=(3, 1), dtype=float64)
# ****
# For epoch  60 , the weights =  tf.Tensor(
# [[-0.1063712 ]
#  [-0.24895465]
#  [ 0.61859837]], shape=(3, 1), dtype=float64)
# ****
# For epoch  61 , the weights =  tf.Tensor(
# [[-0.10646075]
#  [-0.2490442 ]
#  [ 0.61850883]], shape=(3, 1), dtype=float64)
# ****
# For epoch  62 , the weights =  tf.Tensor(
# [[-0.10645294]
#  [-0.24903638]
#  [ 0.61851664]], shape=(3, 1), dtype=float64)
# ****
# For epoch  63 , the weights =  tf.Tensor(
# [[-0.10607309]
#  [-0.24865653]
#  [ 0.61889649]], shape=(3, 1), dtype=float64)
# ****
# For epoch  64 , the weights =  tf.Tensor(
# [[-0.10606461]
#  [-0.24864806]
#  [ 0.61890496]], shape=(3, 1), dtype=float64)
# ****
# For epoch  65 , the weights =  tf.Tensor(
# [[-0.10591505]
#  [-0.2484985 ]
#  [ 0.61905453]], shape=(3, 1), dtype=float64)
# ****
# For epoch  66 , the weights =  tf.Tensor(
# [[-0.10579682]
#  [-0.24838026]
#  [ 0.61917276]], shape=(3, 1), dtype=float64)
# ****
# For epoch  67 , the weights =  tf.Tensor(
# [[-0.10559978]
#  [-0.24818323]
#  [ 0.61936979]], shape=(3, 1), dtype=float64)
# ****
# For epoch  68 , the weights =  tf.Tensor(
# [[-0.10537661]
#  [-0.24796006]
#  [ 0.61959297]], shape=(3, 1), dtype=float64)
# ****
# For epoch  69 , the weights =  tf.Tensor(
# [[-0.10541016]
#  [-0.24799361]
#  [ 0.61955941]], shape=(3, 1), dtype=float64)
# ****
# For epoch  70 , the weights =  tf.Tensor(
# [[-0.10471741]
#  [-0.24730086]
#  [ 0.62025217]], shape=(3, 1), dtype=float64)
# ****
# For epoch  71 , the weights =  tf.Tensor(
# [[-0.10385924]
#  [-0.24644269]
#  [ 0.62111033]], shape=(3, 1), dtype=float64)
# ****
# For epoch  72 , the weights =  tf.Tensor(
# [[-0.10370954]
#  [-0.24629299]
#  [ 0.62126004]], shape=(3, 1), dtype=float64)
# ****
# For epoch  73 , the weights =  tf.Tensor(
# [[-0.10376253]
#  [-0.24634598]
#  [ 0.62120705]], shape=(3, 1), dtype=float64)
# ****
# For epoch  74 , the weights =  tf.Tensor(
# [[-0.1029913 ]
#  [-0.24557474]
#  [ 0.62197828]], shape=(3, 1), dtype=float64)
# ****
# For epoch  75 , the weights =  tf.Tensor(
# [[-0.10250107]
#  [-0.24508451]
#  [ 0.62246851]], shape=(3, 1), dtype=float64)
# ****
# For epoch  76 , the weights =  tf.Tensor(
# [[-0.10147802]
#  [-0.24406146]
#  [ 0.62349156]], shape=(3, 1), dtype=float64)
# ****
# For epoch  77 , the weights =  tf.Tensor(
# [[-0.10105617]
#  [-0.24363961]
#  [ 0.62391341]], shape=(3, 1), dtype=float64)
# ****
# For epoch  78 , the weights =  tf.Tensor(
# [[-0.10072828]
#  [-0.24331173]
#  [ 0.6242413 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  79 , the weights =  tf.Tensor(
# [[-0.10052066]
#  [-0.2431041 ]
#  [ 0.62444892]], shape=(3, 1), dtype=float64)
# ****
# For epoch  80 , the weights =  tf.Tensor(
# [[-0.09962771]
#  [-0.24221115]
#  [ 0.62534187]], shape=(3, 1), dtype=float64)
# ****
# For epoch  81 , the weights =  tf.Tensor(
# [[-0.09943404]
#  [-0.24201748]
#  [ 0.62553554]], shape=(3, 1), dtype=float64)
# ****
# For epoch  82 , the weights =  tf.Tensor(
# [[-0.09862278]
#  [-0.24120622]
#  [ 0.6263468 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  83 , the weights =  tf.Tensor(
# [[-0.09797494]
#  [-0.24055839]
#  [ 0.62699464]], shape=(3, 1), dtype=float64)
# ****
# For epoch  84 , the weights =  tf.Tensor(
# [[-0.09807258]
#  [-0.24065603]
#  [ 0.626897  ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  85 , the weights =  tf.Tensor(
# [[-0.09760545]
#  [-0.24018889]
#  [ 0.62736413]], shape=(3, 1), dtype=float64)
# ****
# For epoch  86 , the weights =  tf.Tensor(
# [[-0.09724458]
#  [-0.23982802]
#  [ 0.627725  ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  87 , the weights =  tf.Tensor(
# [[-0.09655212]
#  [-0.23913557]
#  [ 0.62841745]], shape=(3, 1), dtype=float64)
# ****
# For epoch  88 , the weights =  tf.Tensor(
# [[-0.09632876]
#  [-0.2389122 ]
#  [ 0.62864082]], shape=(3, 1), dtype=float64)
# ****
# For epoch  89 , the weights =  tf.Tensor(
# [[-0.09593185]
#  [-0.23851529]
#  [ 0.62903773]], shape=(3, 1), dtype=float64)
# ****
# For epoch  90 , the weights =  tf.Tensor(
# [[-0.09587975]
#  [-0.23846319]
#  [ 0.62908983]], shape=(3, 1), dtype=float64)
# ****
# For epoch  91 , the weights =  tf.Tensor(
# [[-0.09517081]
#  [-0.23775426]
#  [ 0.62979876]], shape=(3, 1), dtype=float64)
# ****
# For epoch  92 , the weights =  tf.Tensor(
# [[-0.09493011]
#  [-0.23751355]
#  [ 0.63003947]], shape=(3, 1), dtype=float64)
# ****
# For epoch  93 , the weights =  tf.Tensor(
# [[-0.09471591]
#  [-0.23729935]
#  [ 0.63025367]], shape=(3, 1), dtype=float64)
# ****
# For epoch  94 , the weights =  tf.Tensor(
# [[-0.09424912]
#  [-0.23683257]
#  [ 0.63072046]], shape=(3, 1), dtype=float64)
# ****
# For epoch  95 , the weights =  tf.Tensor(
# [[-0.09401452]
#  [-0.23659797]
#  [ 0.63095506]], shape=(3, 1), dtype=float64)
# ****
# For epoch  96 , the weights =  tf.Tensor(
# [[-0.09344079]
#  [-0.23602424]
#  [ 0.63152879]], shape=(3, 1), dtype=float64)
# ****
# For epoch  97 , the weights =  tf.Tensor(
# [[-0.093356  ]
#  [-0.23593944]
#  [ 0.63161358]], shape=(3, 1), dtype=float64)
# ****
# For epoch  98 , the weights =  tf.Tensor(
# [[-0.09277344]
#  [-0.23535688]
#  [ 0.63219614]], shape=(3, 1), dtype=float64)
# ****
# For epoch  99 , the weights =  tf.Tensor(
# [[-0.09218088]
#  [-0.23476433]
#  [ 0.6327887 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  100 , the weights =  tf.Tensor(
# [[-0.09221904]
#  [-0.23480249]
#  [ 0.63275054]], shape=(3, 1), dtype=float64)
# ****
# For epoch  101 , the weights =  tf.Tensor(
# [[-0.09193296]
#  [-0.23451641]
#  [ 0.63303661]], shape=(3, 1), dtype=float64)
# ****
# For epoch  102 , the weights =  tf.Tensor(
# [[-0.09123815]
#  [-0.2338216 ]
#  [ 0.63373143]], shape=(3, 1), dtype=float64)
# ****
# For epoch  103 , the weights =  tf.Tensor(
# [[-0.09123608]
#  [-0.23381953]
#  [ 0.63373349]], shape=(3, 1), dtype=float64)
# ****
# For epoch  104 , the weights =  tf.Tensor(
# [[-0.0910369 ]
#  [-0.23362034]
#  [ 0.63393268]], shape=(3, 1), dtype=float64)
# ****
# For epoch  105 , the weights =  tf.Tensor(
# [[-0.09098272]
#  [-0.23356616]
#  [ 0.63398686]], shape=(3, 1), dtype=float64)
# ****
# For epoch  106 , the weights =  tf.Tensor(
# [[-0.09064008]
#  [-0.23322352]
#  [ 0.6343295 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  107 , the weights =  tf.Tensor(
# [[-0.08995558]
#  [-0.23253902]
#  [ 0.635014  ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  108 , the weights =  tf.Tensor(
# [[-0.08993061]
#  [-0.23251405]
#  [ 0.63503897]], shape=(3, 1), dtype=float64)
# ****
# For epoch  109 , the weights =  tf.Tensor(
# [[-0.08933305]
#  [-0.23191649]
#  [ 0.63563653]], shape=(3, 1), dtype=float64)
# ****
# For epoch  110 , the weights =  tf.Tensor(
# [[-0.08849304]
#  [-0.23107648]
#  [ 0.63647654]], shape=(3, 1), dtype=float64)
# ****
# For epoch  111 , the weights =  tf.Tensor(
# [[-0.08846177]
#  [-0.23104522]
#  [ 0.6365078 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  112 , the weights =  tf.Tensor(
# [[-0.08759642]
#  [-0.23017987]
#  [ 0.63737316]], shape=(3, 1), dtype=float64)
# ****
# For epoch  113 , the weights =  tf.Tensor(
# [[-0.08739038]
#  [-0.22997383]
#  [ 0.6375792 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  114 , the weights =  tf.Tensor(
# [[-0.0870145 ]
#  [-0.22959795]
#  [ 0.63795507]], shape=(3, 1), dtype=float64)
# ****
# For epoch  115 , the weights =  tf.Tensor(
# [[-0.08669276]
#  [-0.2292762 ]
#  [ 0.63827682]], shape=(3, 1), dtype=float64)
# ****
# For epoch  116 , the weights =  tf.Tensor(
# [[-0.08629355]
#  [-0.228877  ]
#  [ 0.63867602]], shape=(3, 1), dtype=float64)
# ****
# For epoch  117 , the weights =  tf.Tensor(
# [[-0.08638822]
#  [-0.22897166]
#  [ 0.63858136]], shape=(3, 1), dtype=float64)
# ****
# For epoch  118 , the weights =  tf.Tensor(
# [[-0.08645723]
#  [-0.22904067]
#  [ 0.63851235]], shape=(3, 1), dtype=float64)
# ****
# For epoch  119 , the weights =  tf.Tensor(
# [[-0.08586207]
#  [-0.22844552]
#  [ 0.63910751]], shape=(3, 1), dtype=float64)
# ****
# For epoch  120 , the weights =  tf.Tensor(
# [[-0.08565736]
#  [-0.22824081]
#  [ 0.63931222]], shape=(3, 1), dtype=float64)
# ****
# For epoch  121 , the weights =  tf.Tensor(
# [[-0.08533977]
#  [-0.22792322]
#  [ 0.63962981]], shape=(3, 1), dtype=float64)
# ****
# For epoch  122 , the weights =  tf.Tensor(
# [[-0.08497903]
#  [-0.22756247]
#  [ 0.63999055]], shape=(3, 1), dtype=float64)
# ****
# For epoch  123 , the weights =  tf.Tensor(
# [[-0.08458226]
#  [-0.22716571]
#  [ 0.64038732]], shape=(3, 1), dtype=float64)
# ****
# For epoch  124 , the weights =  tf.Tensor(
# [[-0.08430684]
#  [-0.22689029]
#  [ 0.64066274]], shape=(3, 1), dtype=float64)
# ****
# For epoch  125 , the weights =  tf.Tensor(
# [[-0.08401151]
#  [-0.22659495]
#  [ 0.64095807]], shape=(3, 1), dtype=float64)
# ****
# For epoch  126 , the weights =  tf.Tensor(
# [[-0.08389653]
#  [-0.22647997]
#  [ 0.64107305]], shape=(3, 1), dtype=float64)
# ****
# For epoch  127 , the weights =  tf.Tensor(
# [[-0.08387237]
#  [-0.22645582]
#  [ 0.6410972 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  128 , the weights =  tf.Tensor(
# [[-0.08366647]
#  [-0.22624991]
#  [ 0.64130311]], shape=(3, 1), dtype=float64)
# ****
# For epoch  129 , the weights =  tf.Tensor(
# [[-0.0833896 ]
#  [-0.22597304]
#  [ 0.64157998]], shape=(3, 1), dtype=float64)
# ****
# For epoch  130 , the weights =  tf.Tensor(
# [[-0.08331441]
#  [-0.22589785]
#  [ 0.64165517]], shape=(3, 1), dtype=float64)
# ****
# For epoch  131 , the weights =  tf.Tensor(
# [[-0.08312516]
#  [-0.2257086 ]
#  [ 0.64184442]], shape=(3, 1), dtype=float64)
# ****
# For epoch  132 , the weights =  tf.Tensor(
# [[-0.08294101]
#  [-0.22552445]
#  [ 0.64202857]], shape=(3, 1), dtype=float64)
# ****
# For epoch  133 , the weights =  tf.Tensor(
# [[-0.08266258]
#  [-0.22524602]
#  [ 0.642307  ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  134 , the weights =  tf.Tensor(
# [[-0.08215467]
#  [-0.22473812]
#  [ 0.6428149 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  135 , the weights =  tf.Tensor(
# [[-0.0819828 ]
#  [-0.22456624]
#  [ 0.64298678]], shape=(3, 1), dtype=float64)
# ****
# For epoch  136 , the weights =  tf.Tensor(
# [[-0.08206616]
#  [-0.22464961]
#  [ 0.64290341]], shape=(3, 1), dtype=float64)
# ****
# For epoch  137 , the weights =  tf.Tensor(
# [[-0.08176346]
#  [-0.2243469 ]
#  [ 0.64320612]], shape=(3, 1), dtype=float64)
# ****
# For epoch  138 , the weights =  tf.Tensor(
# [[-0.08150255]
#  [-0.224086  ]
#  [ 0.64346702]], shape=(3, 1), dtype=float64)
# ****
# For epoch  139 , the weights =  tf.Tensor(
# [[-0.08120018]
#  [-0.22378363]
#  [ 0.6437694 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  140 , the weights =  tf.Tensor(
# [[-0.08128404]
#  [-0.22386749]
#  [ 0.64368554]], shape=(3, 1), dtype=float64)
# ****
# For epoch  141 , the weights =  tf.Tensor(
# [[-0.08107509]
#  [-0.22365853]
#  [ 0.64389449]], shape=(3, 1), dtype=float64)
# ****
# For epoch  142 , the weights =  tf.Tensor(
# [[-0.08113825]
#  [-0.2237217 ]
#  [ 0.64383133]], shape=(3, 1), dtype=float64)
# ****
# For epoch  143 , the weights =  tf.Tensor(
# [[-0.08069934]
#  [-0.22328278]
#  [ 0.64427024]], shape=(3, 1), dtype=float64)
# ****
# For epoch  144 , the weights =  tf.Tensor(
# [[-0.08049183]
#  [-0.22307527]
#  [ 0.64447775]], shape=(3, 1), dtype=float64)
# ****
# For epoch  145 , the weights =  tf.Tensor(
# [[-0.0806458 ]
#  [-0.22322925]
#  [ 0.64432378]], shape=(3, 1), dtype=float64)
# ****
# For epoch  146 , the weights =  tf.Tensor(
# [[-0.08040256]
#  [-0.222986  ]
#  [ 0.64456702]], shape=(3, 1), dtype=float64)
# ****
# For epoch  147 , the weights =  tf.Tensor(
# [[-0.07996581]
#  [-0.22254925]
#  [ 0.64500377]], shape=(3, 1), dtype=float64)
# ****
# For epoch  148 , the weights =  tf.Tensor(
# [[-0.0796709 ]
#  [-0.22225434]
#  [ 0.64529868]], shape=(3, 1), dtype=float64)
# ****
# For epoch  149 , the weights =  tf.Tensor(
# [[-0.07924831]
#  [-0.22183175]
#  [ 0.64572127]], shape=(3, 1), dtype=float64)
# ****
# For epoch  150 , the weights =  tf.Tensor(
# [[-0.07858005]
#  [-0.22116349]
#  [ 0.64638953]], shape=(3, 1), dtype=float64)
# ****
# For epoch  151 , the weights =  tf.Tensor(
# [[-0.0781914 ]
#  [-0.22077485]
#  [ 0.64677818]], shape=(3, 1), dtype=float64)
# ****
# For epoch  152 , the weights =  tf.Tensor(
# [[-0.07792671]
#  [-0.22051016]
#  [ 0.64704287]], shape=(3, 1), dtype=float64)
# ****
# For epoch  153 , the weights =  tf.Tensor(
# [[-0.07733323]
#  [-0.21991668]
#  [ 0.64763634]], shape=(3, 1), dtype=float64)
# ****
# For epoch  154 , the weights =  tf.Tensor(
# [[-0.0773057 ]
#  [-0.21988914]
#  [ 0.64766388]], shape=(3, 1), dtype=float64)
# ****
# For epoch  155 , the weights =  tf.Tensor(
# [[-0.07713156]
#  [-0.219715  ]
#  [ 0.64783802]], shape=(3, 1), dtype=float64)
# ****
# For epoch  156 , the weights =  tf.Tensor(
# [[-0.07720248]
#  [-0.21978592]
#  [ 0.6477671 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  157 , the weights =  tf.Tensor(
# [[-0.07681633]
#  [-0.21939977]
#  [ 0.64815325]], shape=(3, 1), dtype=float64)
# ****
# For epoch  158 , the weights =  tf.Tensor(
# [[-0.07638489]
#  [-0.21896833]
#  [ 0.64858469]], shape=(3, 1), dtype=float64)
# ****
# For epoch  159 , the weights =  tf.Tensor(
# [[-0.07576684]
#  [-0.21835028]
#  [ 0.64920274]], shape=(3, 1), dtype=float64)
# ****
# For epoch  160 , the weights =  tf.Tensor(
# [[-0.07562577]
#  [-0.21820922]
#  [ 0.64934381]], shape=(3, 1), dtype=float64)
# ****
# For epoch  161 , the weights =  tf.Tensor(
# [[-0.07559123]
#  [-0.21817468]
#  [ 0.64937835]], shape=(3, 1), dtype=float64)
# ****
# For epoch  162 , the weights =  tf.Tensor(
# [[-0.07544544]
#  [-0.21802888]
#  [ 0.64952414]], shape=(3, 1), dtype=float64)
# ****
# For epoch  163 , the weights =  tf.Tensor(
# [[-0.07522555]
#  [-0.21780899]
#  [ 0.64974403]], shape=(3, 1), dtype=float64)
# ****
# For epoch  164 , the weights =  tf.Tensor(
# [[-0.07501878]
#  [-0.21760222]
#  [ 0.6499508 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  165 , the weights =  tf.Tensor(
# [[-0.07481062]
#  [-0.21739406]
#  [ 0.65015896]], shape=(3, 1), dtype=float64)
# ****
# For epoch  166 , the weights =  tf.Tensor(
# [[-0.07473924]
#  [-0.21732269]
#  [ 0.65023033]], shape=(3, 1), dtype=float64)
# ****
# For epoch  167 , the weights =  tf.Tensor(
# [[-0.07414408]
#  [-0.21672753]
#  [ 0.65082549]], shape=(3, 1), dtype=float64)
# ****
# For epoch  168 , the weights =  tf.Tensor(
# [[-0.07432561]
#  [-0.21690906]
#  [ 0.65064397]], shape=(3, 1), dtype=float64)
# ****
# For epoch  169 , the weights =  tf.Tensor(
# [[-0.07434576]
#  [-0.21692921]
#  [ 0.65062382]], shape=(3, 1), dtype=float64)
# ****
# For epoch  170 , the weights =  tf.Tensor(
# [[-0.0739083 ]
#  [-0.21649175]
#  [ 0.65106128]], shape=(3, 1), dtype=float64)
# ****
# For epoch  171 , the weights =  tf.Tensor(
# [[-0.07286944]
#  [-0.21545288]
#  [ 0.65210014]], shape=(3, 1), dtype=float64)
# ****
# For epoch  172 , the weights =  tf.Tensor(
# [[-0.07276609]
#  [-0.21534953]
#  [ 0.65220349]], shape=(3, 1), dtype=float64)
# ****
# For epoch  173 , the weights =  tf.Tensor(
# [[-0.07273556]
#  [-0.215319  ]
#  [ 0.65223402]], shape=(3, 1), dtype=float64)
# ****
# For epoch  174 , the weights =  tf.Tensor(
# [[-0.07234324]
#  [-0.21492669]
#  [ 0.65262634]], shape=(3, 1), dtype=float64)
# ****
# For epoch  175 , the weights =  tf.Tensor(
# [[-0.07177934]
#  [-0.21436279]
#  [ 0.65319024]], shape=(3, 1), dtype=float64)
# ****
# For epoch  176 , the weights =  tf.Tensor(
# [[-0.07151491]
#  [-0.21409835]
#  [ 0.65345467]], shape=(3, 1), dtype=float64)
# ****
# For epoch  177 , the weights =  tf.Tensor(
# [[-0.07114808]
#  [-0.21373152]
#  [ 0.6538215 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  178 , the weights =  tf.Tensor(
# [[-0.07113583]
#  [-0.21371928]
#  [ 0.65383375]], shape=(3, 1), dtype=float64)
# ****
# For epoch  179 , the weights =  tf.Tensor(
# [[-0.07093523]
#  [-0.21351867]
#  [ 0.65403435]], shape=(3, 1), dtype=float64)
# ****
# For epoch  180 , the weights =  tf.Tensor(
# [[-0.07036809]
#  [-0.21295153]
#  [ 0.65460149]], shape=(3, 1), dtype=float64)
# ****
# For epoch  181 , the weights =  tf.Tensor(
# [[-0.07021265]
#  [-0.21279609]
#  [ 0.65475693]], shape=(3, 1), dtype=float64)
# ****
# For epoch  182 , the weights =  tf.Tensor(
# [[-0.07016442]
#  [-0.21274787]
#  [ 0.65480516]], shape=(3, 1), dtype=float64)
# ****
# For epoch  183 , the weights =  tf.Tensor(
# [[-0.07024556]
#  [-0.21282901]
#  [ 0.65472401]], shape=(3, 1), dtype=float64)
# ****
# For epoch  184 , the weights =  tf.Tensor(
# [[-0.06994327]
#  [-0.21252671]
#  [ 0.65502631]], shape=(3, 1), dtype=float64)
# ****
# For epoch  185 , the weights =  tf.Tensor(
# [[-0.06968005]
#  [-0.21226349]
#  [ 0.65528953]], shape=(3, 1), dtype=float64)
# ****
# For epoch  186 , the weights =  tf.Tensor(
# [[-0.06915654]
#  [-0.21173998]
#  [ 0.65581304]], shape=(3, 1), dtype=float64)
# ****
# For epoch  187 , the weights =  tf.Tensor(
# [[-0.06894811]
#  [-0.21153156]
#  [ 0.65602146]], shape=(3, 1), dtype=float64)
# ****
# For epoch  188 , the weights =  tf.Tensor(
# [[-0.06857496]
#  [-0.2111584 ]
#  [ 0.65639462]], shape=(3, 1), dtype=float64)
# ****
# For epoch  189 , the weights =  tf.Tensor(
# [[-0.06817344]
#  [-0.21075688]
#  [ 0.65679614]], shape=(3, 1), dtype=float64)
# ****
# For epoch  190 , the weights =  tf.Tensor(
# [[-0.06783701]
#  [-0.21042045]
#  [ 0.65713257]], shape=(3, 1), dtype=float64)
# ****
# For epoch  191 , the weights =  tf.Tensor(
# [[-0.06719007]
#  [-0.20977352]
#  [ 0.65777951]], shape=(3, 1), dtype=float64)
# ****
# For epoch  192 , the weights =  tf.Tensor(
# [[-0.06709087]
#  [-0.20967431]
#  [ 0.65787871]], shape=(3, 1), dtype=float64)
# ****
# For epoch  193 , the weights =  tf.Tensor(
# [[-0.0667508 ]
#  [-0.20933425]
#  [ 0.65821877]], shape=(3, 1), dtype=float64)
# ****
# For epoch  194 , the weights =  tf.Tensor(
# [[-0.06638469]
#  [-0.20896814]
#  [ 0.65858488]], shape=(3, 1), dtype=float64)
# ****
# For epoch  195 , the weights =  tf.Tensor(
# [[-0.06609293]
#  [-0.20867637]
#  [ 0.65887665]], shape=(3, 1), dtype=float64)
# ****
# For epoch  196 , the weights =  tf.Tensor(
# [[-0.06534327]
#  [-0.20792671]
#  [ 0.65962631]], shape=(3, 1), dtype=float64)
# ****
# For epoch  197 , the weights =  tf.Tensor(
# [[-0.06480458]
#  [-0.20738803]
#  [ 0.66016499]], shape=(3, 1), dtype=float64)
# ****
# For epoch  198 , the weights =  tf.Tensor(
# [[-0.06493398]
#  [-0.20751743]
#  [ 0.6600356 ]], shape=(3, 1), dtype=float64)
# ****
# For epoch  199 , the weights =  tf.Tensor(
# [[-0.06495084]
#  [-0.20753429]
#  [ 0.66001874]], shape=(3, 1), dtype=float64)
# ****
# For epoch  200 , the weights =  tf.Tensor(
# [[-0.06481643]
#  [-0.20739988]
#  [ 0.66015315]], shape=(3, 1), dtype=float64)

# %% [markdown]
# Phew! Observed how weights and bias correct themselves on each iteration, and each epoch? It's a long process!

# %% [markdown]
# Let's observe how the loss dropped over a period of time- on the y-axis we have the loss (mean squared error), and epochs on the x-axis

# %%
import matplotlib.pyplot as plt
time_axis = range(1,len(err)+1)
plt.plot(  time_axis, err)
plt.show()

# %% [markdown]
# After this, we can locate the point on the graph with minimum y (because this is an error). That's the point at which we can then retrain the model.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# In this module we achieved the following:
#
#
#
# *   Revised the model training process
# *   Simulated the model training
# *   Observed inbuilt TensorFlow functions
# *   Initialized weights and bias
# *   Observed their updates over iterations and epochs
# *   Calculated and plotted the errors over epochs
